# %%
import numpy as np
import os
import pandas as pd

from os.path import join
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

pd.set_option('display.max_columns', None)

# %%
# load data - sourced from (https://www.kaggle.com/datasets/nishaanamin/march-madness-data?resource=download)
cwd = os.getcwd()
data_dir = join(cwd, "data", "2024")

matchups = pd.read_csv(join(data_dir, "Tournament Matchups.csv")) # seeding and achieved round for each year
results = pd.read_csv(join(data_dir, "Team Results.csv")) # tournament round appearance history
shooting = pd.read_csv(join(data_dir, "Shooting Splits.csv"))
coach = pd.read_csv(join(data_dir, "Coach Results.csv"))

# %%
# join datasets
index_cols = ["TEAM NO", "TEAM", "YEAR"]
data = pd.merge(
    matchups.drop(["CURRENT ROUND", "SCORE"], axis=1).drop_duplicates(index_cols),
    shooting,
    on=index_cols
)

# drop non numeric columns
non_numeric_columns = ["TEAM", "TEAM ID", "CONF"]
data = data.drop(non_numeric_columns, axis=1)

# drop non_predictive columns
non_predictive_cols = ["BY YEAR NO", "BY ROUND NO"]
data = data.drop(non_predictive_cols, axis=1)

# transform ROUND col into # WINS col
round_to_wins_map = {
    "64": 0,
    "32": 1,
    "16": 2,
    "8": 3,
    "4": 4,
    "2": 5,
    "1": 6
}
data.rename(columns={"ROUND": "WINS"}, inplace=True)
data["WINS"].map(round_to_wins_map)
display(data)

data = data[data["YEAR"] < 2024]
# Out:
#      YEAR  TEAM NO  SEED  WINS  DUNKS FG%  DUNKS SHARE  DUNKS FG%D  \
# 0    2024     1076     1     1       89.9         11.9        87.1
# 1    2024     1063    16    64       93.2          6.6        75.0
# 2    2024     1050     2     1       88.1         10.0        89.1
# 3    2024     1070    15    64      100.0          1.9        97.1
# 4    2024     1078     3     1       83.0          9.3        89.9
# ..    ...      ...   ...   ...        ...          ...         ...
# 893  2010      152    14    64       97.3          3.6        89.2
# 894  2010      155     7    64       86.4          3.6        91.7
# 895  2010      153    10    16       91.2          2.9        86.8
# 896  2010      138     2    32       95.2          4.8        89.6
# 897  2010      154    15    64       92.3          3.9        90.9
#
#      DUNKS D SHARE  CLOSE TWOS FG%  CLOSE TWOS SHARE  CLOSE TWOS FG%D  \
# 0              5.8            63.4              45.6             55.9
# 1              4.6            62.4              29.4             53.7
# 2              5.8            67.6              38.2             55.3
# 3              3.4            61.5              35.6             59.3
# 4              7.1            63.6              41.8             59.6
# ..             ...             ...               ...              ...
# 893            3.4            63.5              35.5             63.1
# 894            2.7            62.2              29.8             59.0
# 895            2.6            59.8              37.2             54.2
# 896            4.2            60.4              37.1             58.2
# 897            4.0            58.0              34.0             56.6
#
#      CLOSE TWOS D SHARE  FARTHER TWOS FG%  FARTHER TWOS SHARE  \
# 0                  29.9              37.3                22.5
# 1                  36.7              37.6                36.7
# 2                  28.5              41.2                32.1
# 3                  35.1              38.7                25.5
# 4                  38.1              34.9                10.7
# ..                  ...               ...                 ...
# 893                33.6              35.0                24.5
# 894                30.4              39.1                34.0
# 895                42.8              41.7                26.7
# 896                28.0              37.0                28.5
# 897                31.8              36.3                36.7
#
#      FARTHER TWOS FG%D  FARTHER TWOS D SHARE  THREES FG%  THREES SHARE  \
# 0                 38.9                  31.2        36.9          31.9
# 1                 36.1                  29.5        36.6          33.8
# 2                 34.3                  30.0        34.7          29.7
# 3                 33.2                  25.8        36.7          38.9
# 4                 37.6                  25.4        38.1          47.6
# ..                 ...                   ...         ...           ...
# 893               37.4                  33.1        37.6          40.1
# 894               31.8                  38.4        35.5          36.2
# 895               36.8                  33.8        40.3          36.1
# 896               35.0                  33.4        37.3          34.4
# 897               34.8                  30.0        36.1          29.2
#
#      THREES FG%D  THREES D SHARE  DUNKS FG% RANK  DUNKS SHARE RANK  \
# 0           33.8            38.9             118                11
# 1           38.8            33.8              50               117
# 2           33.4            41.5             164                24
# 3           30.6            39.1               2               350
# 4           32.1            36.5             276                37
# ..           ...             ...             ...               ...
# 893         33.3            33.3              31               206
# 894         30.1            31.2             243               206
# 895         29.7            23.4             155               248
# 896         33.5            38.6              54               127
# 897         32.1            38.2             129               186
#
#      DUNKS FG%D RANK  DUNKS D SHARE RANK  CLOSE TWOS FG% RANK  \
# 0                161                 192                   45
# 1                  6                  87                   65
# 2                224                 192                    8
# 3                360                  21                   78
# 4                251                 309                   41
# ..               ...                 ...                  ...
# 893              151                  65                   98
# 894              229                  26                  128
# 895               87                  22                  192
# 896              160                 167                  169
# 897              202                 140                  235
#
#      CLOSE TWOS SHARE RANK  CLOSE TWOS FG%D RANK  CLOSE TWOS D SHARE RANK  \
# 0                       13                   106                       18
# 1                      344                    43                      170
# 2                      140                    82                        9
# 3                      232                   228                      125
# 4                       61                   245                      215
# ..                     ...                   ...                      ...
# 893                    135                   228                      167
# 894                    268                   129                       93
# 895                     83                    28                      334
# 896                     85                   102                       50
# 897                    164                    73                      120
#
#      FARTHER TWOS FG% RANK  FARTHER TWOS SHARE RANK  FARTHER TWOS FG%D RANK  \
# 0                      253                      252                     174
# 1                      242                       14                      64
# 2                      114                       55                      30
# 3                      203                      182                      12
# 4                      309                      361                     122
# ..                     ...                      ...                     ...
# 893                    175                      321                     275
# 894                     35                      175                      35
# 895                      8                      305                     263
# 896                     83                      282                     181
# 897                    110                      120                     169
#
#      FARTHER TWOS D SHARE RANK  THREES FG% RANK  THREES SHARE RANK  \
# 0                          319               36                302
# 1                          299               44                275
# 2                          305              137                331
# 3                          195               41                142
# 4                          186               13                 13
# ..                         ...              ...                ...
# 893                        173               45                 33
# 894                        290              111                 82
# 895                        194                7                 83
# 896                        185               51                124
# 897                         87               84                260
#
#      THREES FG%D RANK  THREES D SHARE RANK
# 0                 182                  248
# 1                 360                   64
# 2                 151                  309
# 3                  24                  254
# 4                  81                  147
# ..                ...                  ...
# 893               129                  209
# 894                21                  123
# 895                10                    3
# 896               140                  326
# 897                73                  319
#
# [898 rows x 36 columns]

# %%
# set up training/test split
selection_vector = data["YEAR"] % 4 == 0
train = data[~selection_vector]
test = data[selection_vector]

train_y = train["WINS"]
train_x = train.drop("WINS", axis=1)
test_y = train["WINS"]
test_x = train.drop("WINS", axis=1)

# %% [markdown]
# ### basic regression model

# %%
train_x
# Out:
#      YEAR  TEAM NO  SEED  DUNKS FG%  DUNKS SHARE  DUNKS FG%D  DUNKS D SHARE  \
# 68   2023     1011     1       88.7         13.0        85.2            5.3
# 69   2023      955    16       90.0          1.6        97.6            4.1
# 70   2023      979     8       80.2          6.7        86.7            5.8
# 71   2023      945     9       89.7          6.3        92.8            6.9
# 72   2023      961     5       87.5          7.8        75.0            5.4
# ..    ...      ...   ...        ...          ...         ...            ...
# 893  2010      152    14       97.3          3.6        89.2            3.4
# 894  2010      155     7       86.4          3.6        91.7            2.7
# 895  2010      153    10       91.2          2.9        86.8            2.6
# 896  2010      138     2       95.2          4.8        89.6            4.2
# 897  2010      154    15       92.3          3.9        90.9            4.0
#
#      CLOSE TWOS FG%  CLOSE TWOS SHARE  CLOSE TWOS FG%D  CLOSE TWOS D SHARE  \
# 68             60.7              38.9             49.7                32.0
# 69             56.5              41.5             62.6                34.0
# 70             59.9              36.4             55.9                37.0
# 71             60.3              33.3             58.5                39.5
# 72             61.5              31.3             56.8                34.7
# ..              ...               ...              ...                 ...
# 893            63.5              35.5             63.1                33.6
# 894            62.2              29.8             59.0                30.4
# 895            59.8              37.2             54.2                42.8
# 896            60.4              37.1             58.2                28.0
# 897            58.0              34.0             56.6                31.8
#
#      FARTHER TWOS FG%  FARTHER TWOS SHARE  FARTHER TWOS FG%D  \
# 68               34.6                13.9               33.4
# 69               34.1                24.0               42.3
# 70               40.8                26.8               37.3
# 71               40.7                30.5               38.8
# 72               36.7                34.8               38.9
# ..                ...                 ...                ...
# 893              35.0                24.5               37.4
# 894              39.1                34.0               31.8
# 895              41.7                26.7               36.8
# 896              37.0                28.5               35.0
# 897              36.3                36.7               34.8
#
#      FARTHER TWOS D SHARE  THREES FG%  THREES SHARE  THREES FG%D  \
# 68                   38.1        33.5          47.2         28.3
# 69                   24.5        36.4          34.5         33.8
# 70                   31.1        32.8          36.9         32.3
# 71                   25.4        35.0          36.3         34.0
# 72                   25.3        34.0          33.9         28.3
# ..                    ...         ...           ...          ...
# 893                  33.1        37.6          40.1         33.3
# 894                  38.4        35.5          36.2         30.1
# 895                  33.8        40.3          36.1         29.7
# 896                  33.4        37.3          34.4         33.5
# 897                  30.0        36.1          29.2         32.1
#
#      THREES D SHARE  DUNKS FG% RANK  DUNKS SHARE RANK  DUNKS FG%D RANK  \
# 68             30.0             160                 5               92
# 69             41.5             123               355              362
# 70             31.9             330               116              137
# 71             35.1             132               139              315
# 72             40.0             200                78                5
# ..              ...             ...               ...              ...
# 893            33.3              31               206              151
# 894            31.2             243               206              229
# 895            23.4             155               248               87
# 896            38.6              54               127              160
# 897            38.2             129               186              202
#
#      DUNKS D SHARE RANK  CLOSE TWOS FG% RANK  CLOSE TWOS SHARE RANK  \
# 68                  145                  115                     95
# 69                   50                  261                     35
# 70                  191                  127                    175
# 71                  282                  121                    262
# 72                  156                   96                    315
# ..                  ...                  ...                    ...
# 893                  65                   98                    135
# 894                  26                  128                    268
# 895                  22                  192                     83
# 896                 167                  169                     85
# 897                 140                  235                    164
#
#      CLOSE TWOS FG%D RANK  CLOSE TWOS D SHARE RANK  FARTHER TWOS FG% RANK  \
# 68                      3                       50                    310
# 69                    317                      101                    321
# 70                     75                      221                     81
# 71                    163                      297                     84
# 72                    110                      125                    243
# ..                    ...                      ...                    ...
# 893                   228                      167                    175
# 894                   129                       93                     35
# 895                    28                      334                      8
# 896                   102                       50                     83
# 897                    73                      120                    110
#
#      FARTHER TWOS SHARE RANK  FARTHER TWOS FG%D RANK  \
# 68                       361                      24
# 69                       249                     324
# 70                       175                     135
# 71                        85                     203
# 72                        20                     209
# ..                       ...                     ...
# 893                      321                     275
# 894                      175                      35
# 895                      305                     263
# 896                      282                     181
# 897                      120                     169
#
#      FARTHER TWOS D SHARE RANK  THREES FG% RANK  THREES SHARE RANK  \
# 68                         363              198                  9
# 69                         118               59                273
# 70                         328              245                198
# 71                         148              122                218
# 72                         144              175                284
# ..                         ...              ...                ...
# 893                        173               45                 33
# 894                        290              111                 82
# 895                        194                7                 83
# 896                        185               51                124
# 897                         87               84                260
#
#      THREES FG%D RANK  THREES D SHARE RANK
# 68                  4                   10
# 69                170                  312
# 70                 82                   31
# 71                184                  111
# 72                  4                  280
# ..                ...                  ...
# 893               129                  209
# 894                21                  123
# 895                10                    3
# 896               140                  326
# 897                73                  319
#
# [702 rows x 35 columns]

# %%
# fit model
model = LinearRegression()
model.fit(train_x, train_y)
pred = model.predict(test_x)

# Calculate the model performance
mse = mean_squared_error(test_y, pred)
r2 = r2_score(test_y, pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 321.02054319072334
# R² Score: 0.3812355992834231

# %% [markdown]
# ### advanced ML model

# %%
# fit model

# %% [markdown]
# ### Neural net model

# %%
# fit model
